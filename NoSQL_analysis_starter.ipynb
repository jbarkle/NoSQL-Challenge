# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
pprint(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {'scores.Hygiene': 20}
result = list(establishments.find(hygiene_query))

# %%
# Use count_documents to display the number of documents in the result
hygiene_result = (f"Number of documents in result:", establishments.count_documents(hygiene_query))
pprint(hygiene_result)
# Out:
# ('Number of documents in result:', 41)

# %%
# Display the first document in the results using pprint
pprint(result[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64cb18ff8dc1f50420606742'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_df = pd.DataFrame(result)

# %%
# Display the number of rows in the DataFrame
rows = len(hygiene_df)
rows
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64cb18ff8dc1f50420606742   110681                  0
# 1  64cb18ff8dc1f50420606ab1   612039                  0
# 2  64cb18ff8dc1f50420606dbe   730933                  0
# 3  64cb18ff8dc1f50420606fab   172735                  0
# 4  64cb18ff8dc1f50420606fbb   172953                  0
# 5  64cb18ff8dc1f5042060795d   512854                  0
# 6  64cb18ff8dc1f50420607b7a  1537089                  0
# 7  64cb18ff8dc1f504206090c1   155648                  0
# 8  64cb18ff8dc1f504206094e0  1012883                  0
# 9  64cb18ff8dc1f50420609d03   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
auth_query = {"LocalAuthorityName":{"$regex":"London"},
                "RatingValue":{"$gte":4}}
lon_results = list(establishments.find(auth_query))

# %%
# Use count_documents to display the number of documents in the result
auth_results = (f"Number of documents in result:", establishments.count_documents(auth_query))
pprint(auth_results)
# Out:
# ('Number of documents in result:', 33)

# %%
# Display the first document in the results using pprint
pprint(lon_results[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64cb18ff8dc1f5042060814c'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Convert the result to a Pandas DataFrame
auth_df = pd.DataFrame(lon_results)

# %%
# Display the number of rows in the DataFrame
auth_rows = len(auth_df)
auth_rows
# Out:
# 33

# %%
# Display the first 10 rows of the DataFrame
auth_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64cb18ff8dc1f5042060814c   621707                  0
# 1  64cb18ff8dc1f5042060846a  1130836                  0
# 2  64cb18ff8dc1f50420608fc2   293783                  0
# 3  64cb18ff8dc1f50420609dbd   294474                  0
# 4  64cb18ff8dc1f50420609dbf  1315095                  0
# 5  64cb18ff8dc1f5042060a4cb   294900                  0
# 6  64cb18ff8dc1f5042060c5ce   293756                  0
# 7  64cb18ff8dc1f5042060c99e   878523                  0
# 8  64cb18ff8dc1f5042060c9b7   294606                  0
# 9  64cb18ff8dc1f5042060c9b9   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {"RatingValue": 5,
        "geocode.latitude": {"$lte": (latitude + degree_search), "$gte": (latitude - degree_search)},
        "geocode.longitude": {"$lte": (longitude + degree_search), "$gte": (longitude - degree_search)}}
limit = 5
sort =  [("scores.Hygiene", 1)]

# Print the results
rated_results = list(establishments.find(query).sort(sort).limit(limit))
pprint(rated_results)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64cb18ff8dc1f5042060bf75'),
#   'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
# ...

# %%
# Convert result to Pandas DataFrame
rated_df = pd.DataFrame(rated_results)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_hygiene_query = {"$match": {"scores.Hygiene": 0}}
# 2. Groups the matches by Local Authority
group_hygiene_query = {"$group": {"_id": {"LocalAuthorityName": "$LocalAuthorityName"},
                         "count": {"$sum": 1}}}
# 3. Sorts the matches from highest to lowest
sort_hygiene_values = {"$sort": {"count": -1}}
# Create a pipeline
pipeline = [match_hygiene_query, group_hygiene_query, sort_hygiene_values]
# Aggregate
pipeline_results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
pprint(len(pipeline_results))
# Out:
# 55

# %%
# Print the first 10 results
pprint(pipeline_results[0:10])
# Out:
# [{'_id': {'LocalAuthorityName': 'Thanet'}, 'count': 1130},
#  {'_id': {'LocalAuthorityName': 'Greenwich'}, 'count': 882},
#  {'_id': {'LocalAuthorityName': 'Maidstone'}, 'count': 713},
#  {'_id': {'LocalAuthorityName': 'Newham'}, 'count': 711},
#  {'_id': {'LocalAuthorityName': 'Swale'}, 'count': 686},
#  {'_id': {'LocalAuthorityName': 'Chelmsford'}, 'count': 680},
#  {'_id': {'LocalAuthorityName': 'Medway'}, 'count': 672},
#  {'_id': {'LocalAuthorityName': 'Bexley'}, 'count': 607},
#  {'_id': {'LocalAuthorityName': 'Southend-On-Sea'}, 'count': 586},
#  {'_id': {'LocalAuthorityName': 'Tendring'}, 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
pipeline_df = pd.json_normalize(pipeline_results)

# %%
# Display the number of rows in the DataFrame
pipeline_rows = len(pipeline_df)
pipeline_rows
# Out:
# 55

# %%
# Display the first 10 rows of the DataFrame
pipeline_df.head(10)
# Out:
#    count _id.LocalAuthorityName
# 0   1130                 Thanet
# 1    882              Greenwich
# 2    713              Maidstone
# 3    711                 Newham
# 4    686                  Swale
# 5    680             Chelmsford
# 6    672                 Medway
# 7    607                 Bexley
# 8    586        Southend-On-Sea
# 9    542               Tendring
